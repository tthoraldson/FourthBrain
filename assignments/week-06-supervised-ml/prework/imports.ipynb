# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import plotly 
import sklearn 
import shap
import tpot
import streamlit as st

# %%
# %pip install shap tpot streamlit
# Out:
# Requirement already satisfied: shap in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (0.41.0)
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.2 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.15.2-py2.py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: slicer==0.0.7 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (0.56.4)
# Requirement already satisfied: scikit-learn in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (1.0.2)
# Requirement already satisfied: tqdm>4.25.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (4.64.1)
# Requirement already satisfied: numpy in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (1.23.4)
# Requirement already satisfied: packaging>20.9 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (21.3)
# Requirement already satisfied: scipy in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (1.9.3)
# Requirement already satisfied: cloudpickle in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (2.2.0)
# Requirement already satisfied: pandas in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from shap) (1.5.1)
# Requirement already satisfied: update-checker>=0.16 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from tpot) (0.18.0)
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp310-cp310-macosx_10_15_x86_64.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 2.7 MB/s eta 0:00:00
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.7.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: joblib>=0.13.2 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from tpot) (1.2.0)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 3.5 MB/s eta 0:00:00m eta 0:00:01
# Collecting blinker>=1.0.0
#   Using cached blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 1.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (4.3.0)
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 2.8 MB/s eta 0:00:004.6 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.4 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (5.0.0)
# Collecting validators>=0.2
#   Using cached validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp310-cp310-macosx_10_14_x86_64.whl (25.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (9.3.0)
# Requirement already satisfied: tornado>=5.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (6.2)
# Collecting altair>=3.2.0
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# Collecting cachetools>=4.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: python-dateutil in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Collecting semver
#   Using cached semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting tzlocal>=1.1
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: click>=7.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: jinja2 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from altair>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: entrypoints in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from altair>=3.2.0->streamlit) (0.4)
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 1.7 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from requests>=2.4->streamlit) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from requests>=2.4->streamlit) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from requests>=2.4->streamlit) (3.4)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from scikit-learn->shap) (3.1.0)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from numba->shap) (63.4.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/theresa/opt/anaconda3/envs/sa/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Collecting tzdata
#   Using cached tzdata-2022.7-py2.py3-none-any.whl (340 kB)
# Building wheels for collected packages: stopit, validators
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=a6827589fdc207483adc9c7491dceb11dfb208f707ca71a122fe5ac411b1d4ac
#   Stored in directory: /Users/theresa/Library/Caches/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=5205d98e7ab1dca1db22bf60e500c114e0bb1dfb85a7c948c5022a4229b3a41e
#   Stored in directory: /Users/theresa/Library/Caches/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built stopit validators
# Installing collected packages: stopit, commonmark, validators, tzdata, toolz, toml, smmap, semver, rich, pympler, pyarrow, protobuf, deap, cachetools, blinker, xgboost, pytz-deprecation-shim, pydeck, gitdb, tzlocal, tpot, gitpython, altair, streamlit
# Successfully installed altair-4.2.0 blinker-1.5 cachetools-5.2.0 commonmark-0.9.1 deap-1.3.3 gitdb-4.0.10 gitpython-3.1.29 protobuf-3.20.3 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.6.0 semver-2.13.0 smmap-5.0.0 stopit-1.1.2 streamlit-1.15.2 toml-0.10.2 toolz-0.12.0 tpot-0.11.7 tzdata-2022.7 tzlocal-4.2 validators-0.20.0 xgboost-1.7.1
# Note: you may need to restart the kernel to use updated packages.
