# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://user-images.githubusercontent.com/37101144/161836199-fdb0219d-0361-4988-bf26-48b0fad160a3.png"
#      width="200px"
#      height="auto"/>
# </p>

# %% [markdown]
# # <h1 align="center" id="heading">Subscription Prediction with Delta Lake, PySpark, and MLlib</h1>

# %% [markdown]
# # Spark Environment
#
# Make sure that you open this notebook in your Spark environment!

# %%
# !pip install -U -q pyspark delta-spark # If you use Colab uncomment this line
# !pip install pyspark
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 11.7 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.8/dist-packages (3.3.1)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.8/dist-packages (from pyspark) (0.10.9.5)

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of this session, you will be able to
#
# - Load, save, partition data with Delta Lake tables
# - Explore data with Spark DataFrames
# - Build a pipeline in MLlib for machine learning workflow
# - Fit a logistic regression model, make predictions, and evaluate the model

# %% [markdown]
# ## Part 1: Data Loader
#
# We are using a dataset from the UCI Machine Learning Repository.
#
# 1. Use `wget` to download the dataset. Then use `ls` to verify that the `bank.zip` file is downloaded.

# %%
# %%sh
# wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip
# Out:
# --2023-02-05 22:06:22--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 579043 (565K) [application/x-httpd-php]
# Saving to: ‘bank.zip’
#
#      0K .......... .......... .......... .......... ..........  8%  388K 1s
#     50K .......... .......... .......... .......... .......... 17%  793K 1s
#    100K .......... .......... .......... .......... .......... 26% 42.4M 1s
#    150K .......... .......... .......... .......... .......... 35%  801K 0s
#    200K .......... .......... .......... .......... .......... 44% 44.0M 0s
#    250K .......... .......... .......... .......... .......... 53% 44.1M 0s
#    300K .......... .......... .......... .......... .......... 61%  816K 0s
#    350K .......... .......... .......... .......... .......... 70% 89.9M 0s
#    400K .......... .......... .......... .......... .......... 79% 66.6M 0s
#    450K .......... .......... .......... .......... .......... 88% 98.4M 0s
#    500K .......... .......... .......... .......... .......... 97%  111M 0s
#    550K .......... .....                                      100%  127M=0.3s
#
# 2023-02-05 22:06:22 (1.72 MB/s) - ‘bank.zip’ saved [579043/579043]

# %%
ls
# Out:
# bank.zip  sample_data/

# %% [markdown]
# 2. Unzip the file and use `ls` to see the files.

# %%
# %%sh
# unzip bank.zip
# Out:
# Archive:  bank.zip
#   inflating: bank-full.csv
#   inflating: bank-names.txt
#   inflating: bank.csv

# %%
ls -lh
# Out:
# total 5.5M
# -rw-r--r-- 1 root root 451K Feb 14  2012 bank.csv
# -rw-r--r-- 1 root root 4.4M Feb 14  2012 bank-full.csv
# -rw-r--r-- 1 root root 3.8K Feb 14  2012 bank-names.txt
# -rw-r--r-- 1 root root 566K Feb 14  2012 bank.zip
# drwxr-xr-x 1 root root 4.0K Feb  2 14:40 sample_data/

# %% [markdown]
# 3. Inspect the dataset and note if there is anything to be aware of in the dataset structure.

# %%
# %%sh
# wc -l bank.csv
# Out:
# 4522 bank.csv

# %%
# %%sh
# head bank.csv
# Out:
# "age";"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 30;"unemployed";"married";"primary";"no";1787;"no";"no";"cellular";19;"oct";79;1;-1;0;"unknown";"no"
# 33;"services";"married";"secondary";"no";4789;"yes";"yes";"cellular";11;"may";220;1;339;4;"failure";"no"
# 35;"management";"single";"tertiary";"no";1350;"yes";"no";"cellular";16;"apr";185;1;330;1;"failure";"no"
# 30;"management";"married";"tertiary";"no";1476;"yes";"yes";"unknown";3;"jun";199;4;-1;0;"unknown";"no"
# 59;"blue-collar";"married";"secondary";"no";0;"yes";"no";"unknown";5;"may";226;1;-1;0;"unknown";"no"
# 35;"management";"single";"tertiary";"no";747;"no";"no";"cellular";23;"feb";141;2;176;3;"failure";"no"
# 36;"self-employed";"married";"tertiary";"no";307;"yes";"no";"cellular";14;"may";341;1;330;2;"other";"no"
# 39;"technician";"married";"secondary";"no";147;"yes";"no";"cellular";6;"may";151;2;-1;0;"unknown";"no"
# 41;"entrepreneur";"married";"tertiary";"no";221;"yes";"no";"unknown";14;"may";57;2;-1;0;"unknown";"no"

# %% [markdown]
# 4. Create a Delta table for `bank.csv` (Why Delta Lake? Here's a read [here](https://medium.com/@databeans-blogs/delta-lake-the-data-engineers-missing-piece-part-1-ebab66a3f8c0?source) from a data engineer's perspective)
#
#     We first set up a Python project `ml-bank`, configure the SparkSession with the `configure_spark_with_delta_pip()` utility function in Delta Lake:

# %%
import pyspark
from delta import *

builder = pyspark.sql.SparkSession.builder.appName("ml-bank") \
  .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
  .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %% [markdown]
# 5. We define output formats and paths, you need to complete code to load the data from its source (since the delimiter of the file is semicolon, use [`spark.read.csv`](https://spark.apache.org/docs/latest/sql-data-sources-csv.html) that provides more flexibility) and write the data to its target (hint: [Create a table](https://docs.databricks.com/delta/delta-batch.html)).
#
#
# __NOTE__ Databricks requires all the paths to be absolute, not relative. To check the absolute path, run `pwd` bash command.

# %%
# Define the input and output formats and paths and the table name.
write_format = 'delta'
load_path = 'file:/databricks/driver/bank.csv'
save_path = 'file:/databricks/driver/tmp/delta/bank-4k'
table_name = 'default.bank4k'

# Load the data from its source into a dataframe.
data = spark.read.csv('bank.csv', inferSchema=True, header=True, sep=';')
data.show(5)

# Create table with path using DataFrame's schema and write data to it
# Note if you are overwriting to specificy overwrite option
data.write.saveAsTable(table_name, format=write_format, mode='overwrite')
# Out:
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# |age|        job|marital|education|default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|  y|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# | 30| unemployed|married|  primary|     no|   1787|     no|  no|cellular| 19|  oct|      79|       1|   -1|       0| unknown| no|
# | 33|   services|married|secondary|     no|   4789|    yes| yes|cellular| 11|  may|     220|       1|  339|       4| failure| no|
# | 35| management| single| tertiary|     no|   1350|    yes|  no|cellular| 16|  apr|     185|       1|  330|       1| failure| no|
# | 30| management|married| tertiary|     no|   1476|    yes| yes| unknown|  3|  jun|     199|       4|   -1|       0| unknown| no|
# | 59|blue-collar|married|secondary|     no|      0|    yes|  no| unknown|  5|  may|     226|       1|   -1|       0| unknown| no|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# only showing top 5 rows

# %% [markdown]
# 6. Verify what we just created.

# %%
ls -lh /databricks/driver/tmp/delta/bank-4k/
# Out:
# ls: cannot access '/databricks/driver/tmp/delta/bank-4k/': No such file or directory

# %% [markdown]
# 7. Partition data by `job` status.
#
#   To speed up queries that have predicates involving the partition columns, we should partition data. Often time, we partition by anonymized user id; here we demonstrate the idea with `job`.
#
# __NOTE__ We saw previously that the data can be loaded in Delta lake as one table. Now to partition the data, we need to remove the existing directory, or load it into a different directoty. The goal is to showcase delta lake capabilities.

# %%
ls spark-warehouse/bank4k
# Out:
# _delta_log/
# part-00000-58119500-983f-4d3f-a4a4-d2aad995d730-c000.snappy.parquet

# %%
import shutil
colab_save_path = 'spark-warehouse/bank4k'
shutil.rmtree(colab_save_path) # To replace data, we need to remove the existing directory

# %%
partition_by = 'job'
data.show(5)
# Write the data to its target.
data.write.format(write_format).partitionBy(partition_by).option("overwriteSchema", "true").mode('overwrite').save(save_path)
# Out:
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# |age|        job|marital|education|default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|  y|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# | 30| unemployed|married|  primary|     no|   1787|     no|  no|cellular| 19|  oct|      79|       1|   -1|       0| unknown| no|
# | 33|   services|married|secondary|     no|   4789|    yes| yes|cellular| 11|  may|     220|       1|  339|       4| failure| no|
# | 35| management| single| tertiary|     no|   1350|    yes|  no|cellular| 16|  apr|     185|       1|  330|       1| failure| no|
# | 30| management|married| tertiary|     no|   1476|    yes| yes| unknown|  3|  jun|     199|       4|   -1|       0| unknown| no|
# | 59|blue-collar|married|secondary|     no|      0|    yes|  no| unknown|  5|  may|     226|       1|   -1|       0| unknown| no|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# only showing top 5 rows

# %%
ls -lh /databricks/driver/tmp/delta/bank-4k/
# Out:
# total 52K
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07  _delta_log/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=admin.'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=blue-collar'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=entrepreneur'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=housemaid'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=management'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=retired'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=self-employed'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=services'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=student'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=technician'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=unemployed'/
# drwxr-xr-x 2 root root 4.0K Feb  5 22:07 'job=unknown'/

# %% [markdown]
#   We only touch the surface of Delta Lake, for more information, check [Delta Lake guide](https://docs.databricks.com/delta/index.html)

# %% [markdown]
# ## Part 2: Exploring The Data
#
# We will use the direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict whether the client will subscribe (Yes/No) to a term deposit.

# %% [markdown]
# 1. Load data from its source by specifying the data format and path; then check out the schemas.

# %%
read_format = 'delta'
load_path = '/tmp/delta/bank-4k/' # does not work in colab
temp = '/databricks/driver/tmp/delta/bank-4k/'

df = spark.read.format(read_format).load(temp) 

df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)

# %% [markdown]
# Here are the columns you should see:
#
# * Input variables: age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome
#
# * Output variable: y (deposit)
#
# 2. Have a peek of the first five observations. Use the `.show()` method.

# %%
df.show(5)
# Out:
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# |age|        job|marital|education|default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|  y|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# | 59|blue-collar|married|secondary|     no|      0|    yes|  no| unknown|  5|  may|     226|       1|   -1|       0| unknown| no|
# | 31|blue-collar|married|secondary|     no|    360|    yes| yes|cellular| 29|  jan|      89|       1|  241|       1| failure| no|
# | 25|blue-collar| single|  primary|     no|   -221|    yes|  no| unknown| 23|  may|     250|       1|   -1|       0| unknown| no|
# | 55|blue-collar|married|  primary|     no|    627|    yes|  no| unknown|  5|  may|     247|       1|   -1|       0| unknown| no|
# | 32|blue-collar|married|secondary|     no|   2089|    yes|  no|cellular| 14|  nov|     132|       1|   -1|       0| unknown|yes|
# +---+-----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# only showing top 5 rows

# %% [markdown]
# To get a prettier result, it can be nice to use Pandas to display our DataFrame. Use the Spark `.take()` method to get the first 5 rows and then convert to a pandas DataFrame. Don't forget to pass along the column names. You should see the same result as above, but in a more aesthetically appealing format.

# %%
import pandas as pd
pd_df = pd.DataFrame(df.take(5), columns=df.columns)
pd_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   59  blue-collar  married  secondary      no        0     yes   no
# 1   31  blue-collar  married  secondary      no      360     yes  yes
# 2   25  blue-collar   single    primary      no     -221     yes   no
# 3   55  blue-collar  married    primary      no      627     yes   no
# 4   32  blue-collar  married  secondary      no     2089     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome    y
# 0   unknown    5   may       226         1     -1         0  unknown   no
# 1  cellular   29   jan        89         1    241         1  failure   no
# 2   unknown   23   may       250         1     -1         0  unknown   no
# 3   unknown    5   may       247         1     -1         0  unknown   no
# 4  cellular   14   nov       132         1     -1         0  unknown  yes

# %% [markdown]
# 3. We can also perform transformations on our DataFrame using the Pandas commands that we know and love using the [Pandas on Spark API](https://spark.apache.org/docs/latest/api/python/user_guide/pandas_on_spark/index.html) **(new on Spark versions >= 3.2)**.  Pandas on Spark API was born out of the Databricks project, Koalas 🐨, allows us to use the Pandas commands and aesthetically pleasing output that we know and love distributed on the speed and scale of Spark!  For a nice quickstart on Pandas on Spark, check out this [article](https://towardsdatascience.com/run-pandas-as-fast-as-spark-f5eefe780c45)!  Let's convert our Spark DataFrame to a Pandas on Spark DataFrame!

# %%
import pyspark.pandas as ps

psdf = df.pandas_api()
psdf.head(5)
# Out:
#    age         job   marital education default  balance housing loan   contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   35  management    single  tertiary      no     1350     yes   no  cellular   16   apr       185         1    330         1  failure  no
# 1   30  management   married  tertiary      no     1476     yes  yes   unknown    3   jun       199         4     -1         0  unknown  no
# 2   35  management    single  tertiary      no      747      no   no  cellular   23   feb       141         2    176         3  failure  no
# 3   40  management   married  tertiary      no      194      no  yes  cellular   29   aug       189         2     -1         0  unknown  no
# 4   38  management  divorced   unknown      no        0     yes   no  cellular   18   nov        96         2     -1         0  unknown  no

# %% [markdown]
# 4. How many datapoints are there in the dataset? Use the `.count()` method.

# %%
psdf.count()
# Out:
# age          4521
# job          4521
# marital      4521
# education    4521
# default      4521
# balance      4521
# housing      4521
# loan         4521
# contact      4521
# day          4521
# month        4521
# duration     4521
# campaign     4521
# pdays        4521
# previous     4521
# poutcome     4521
# y            4521
# dtype: int64

# %% [markdown]
# 5. Use the `.describe()` method to see summary statistics on the features.

# %%
psdf.describe()
# Out:
#                age       balance          day     duration     campaign        pdays     previous
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630    39.766645     0.542579
# std      10.576211   3009.638142     8.247667   259.856633     3.109807   100.121124     1.693562
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000    -1.000000     0.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000    -1.000000     0.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000    -1.000000     0.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000    -1.000000     0.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000   871.000000    25.000000

# %% [markdown]
# 6. The above result includes the columns that are categorical, so those columns don't have useful summary statistics. Let's inspect just the numeric features.
#
#     `numeric_features` is defined below to contain the column names of the numeric features.  Notice we use the `zip` functions to iterate through two lists at the same time!
#
#     Filter the DataFrame as you would in pandas to select only the numeric features from the DataFrame and then get the summary statistics on the resulting DataFrame as we did above.

# %%
col_names = [name for name in psdf.dtypes.index]
dtypes = [dtype for dtype in psdf.dtypes.tolist()]

numeric_features = [name for name, dtype in zip(col_names, dtypes) if dtype == 'int32']
numeric_psdf = psdf[numeric_features]
numeric_psdf.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   35     1350   16       185         1    330         1
# 1   30     1476    3       199         4     -1         0
# 2   35      747   23       141         2    176         3
# 3   40      194   29       189         2     -1         0
# 4   38        0   18        96         2     -1         0

# %% [markdown]
# 7. Run the following code to look at correlation between the numeric features.  Let's convert our Pandas on Spark DataFrame to a Pandas DataFrame using the `to_pandas()` command. This will enable us to plot the data.  What do you see?
# - It doesn't seem that any of the features are correlated at all.

# %%
# Convert Pandas on Spark DataFrame to Spark DataFrame
numeric_data = psdf[numeric_features].to_pandas()

axs = pd.plotting.scatter_matrix(numeric_data, figsize=(8, 8));
n = len(numeric_data.columns)

for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n - 1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())
# Out:
# /usr/local/lib/python3.8/dist-packages/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %% [markdown]
# There aren't any highly correlated variables, implying that we can keep them all for the model. However, day and month columns are not really useful, so will remove these two columns.
#
# 8. Use the `.drop()` method to remove the `month` and `day` columns.
#
#     Note that this method returns a new DataFrame, so save that result as `sdf`.
#
#     Use the `.dtypes` method to verify that `sdf` now has the correct columns.

# %%
psdf.drop(['month', 'day'], axis=1)
# Out:
#      age          job   marital  education default  balance housing loan    contact  duration  campaign  pdays  previous poutcome    y
# 0     35   management    single   tertiary      no     1350     yes   no   cellular       185         1    330         1  failure   no
# 1     30   management   married   tertiary      no     1476     yes  yes    unknown       199         4     -1         0  unknown   no
# 2     35   management    single   tertiary      no      747      no   no   cellular       141         2    176         3  failure   no
# 3     40   management   married   tertiary      no      194      no  yes   cellular       189         2     -1         0  unknown   no
# 4     38   management  divorced    unknown      no        0     yes   no   cellular        96         2     -1         0  unknown   no
# 5     42   management  divorced   tertiary      no       16      no   no   cellular       140         3     -1         0  unknown   no
# 6     41   management   married   tertiary      no     5883      no   no   cellular       182         2     -1         0  unknown   no
# 7     59   management   married  secondary      no       42      no   no   cellular        40         1     -1         0  unknown   no
# 8     32   management    single   tertiary      no     2536     yes   no   cellular       958         6     -1         0  unknown  yes
# 9     33   management   married  secondary      no     3935     yes   no   cellular       765         1    342         2  failure  yes
# 10    38   management    single   tertiary      no    11971     yes   no    unknown       609         2    101         3  failure   no
# 11    36   management    single   tertiary      no      553      no   no   cellular       106         2     -1         0  unknown   no
# 12    34   management    single   tertiary      no      872     yes   no    unknown       105         2     -1         0  unknown   no
# 13    57   management   married  secondary      no       82      no  yes  telephone       140         1     -1         0  unknown   no
# 14    48   management   married   tertiary      no     5887      no   no   cellular       227         2     -1         0  unknown   no
# 15    41   management   married  secondary      no        0      no  yes   cellular       630         3     -1         0  unknown   no
# 16    37   management   married   tertiary      no        0      no   no   cellular       268         2    182         3  success  yes
# 17    31   management    single   tertiary      no     6248     yes   no    unknown       154         2     -1         0  unknown   no
# 18    54   management  divorced   tertiary      no     3222      no   no   cellular        67         2     -1         0  unknown   no
# 19    37   management   married   tertiary      no     1315      no   no   cellular       224         1     -1         0  unknown  yes
# 20    32   management    single   tertiary      no     3616      no   no   cellular       165         2     -1         0  unknown   no
# 21    38   management    single   tertiary      no      493     yes   no   cellular       553         1    367         7  failure   no
# 22    34   management    single  secondary      no      524      no   no    unknown         9         1     -1         0  unknown   no
# 23    32   management    single   tertiary      no      574     yes   no   cellular       259         2    145         3  failure   no
# 24    58   management   married   tertiary      no     1517     yes   no  telephone         7         5     -1         0  unknown   no
# 25    46   management  divorced   tertiary      no       25      no   no    unknown       564         2     -1         0  unknown   no
# 26    51   management    single   tertiary     yes      -55     yes   no   cellular       281         2    266         6  failure   no
# 27    33   management    single   tertiary      no        0      no   no   cellular       236        10     -1         0  unknown   no
# 28    34   management    single   tertiary      no        0      no   no   cellular        71         1     -1         0  unknown   no
# 29    52   management   married   tertiary      no     -970     yes   no   cellular       489         1     -1         0  unknown  yes
# 30    60   management   married    unknown      no     6313      no   no    unknown        39         2     -1         0  unknown   no
# 31    32   management  divorced   tertiary      no      948      no   no   cellular       204         2     -1         0  unknown   no
# 32    32   management    single   tertiary      no        0     yes   no   cellular       455         2     -1         0  unknown   no
# 33    31   management    single   tertiary      no      874     yes   no   cellular       190         2     -1         0  unknown   no
# 34    35   management   married   tertiary      no      106      no  yes   cellular       588         2     -1         0  unknown   no
# 35    36   management    single   tertiary      no      442     yes  yes   cellular       102         3     -1         0  unknown   no
# 36    28   management    single   tertiary      no       80      no   no   cellular       676         2    146         2  failure  yes
# 37    37   management    single   tertiary      no       37      no   no   cellular       253         2     -1         0  unknown   no
# 38    42   management   married   tertiary      no     9009      no   no   cellular       135         2     -1         0  unknown   no
# 39    30   management    single   tertiary      no     1372      no   no   cellular       240         2     -1         0  unknown   no
# 40    39   management  divorced   tertiary      no     1315     yes   no   cellular      1337         4    126         1  failure   no
# 41    31   management   married   tertiary     yes     -253      no   no   cellular       220         4     -1         0  unknown   no
# 42    42   management   married   tertiary      no      372     yes   no   cellular       654         2     -1         0  unknown  yes
# 43    54   management   married    primary      no     1691     yes   no   cellular       186         1     -1         0  unknown   no
# 44    44   management   married   tertiary      no     3762      no   no   cellular       125        12     -1         0  unknown   no
# 45    36   management   married   tertiary      no        0     yes   no   cellular        60         1    250         1    other   no
# 46    42   management   married  secondary      no     -189     yes   no    unknown       247         2     -1         0  unknown   no
# 47    42   management   married   tertiary      no      484     yes   no   cellular       144         2     -1         0  unknown   no
# 48    31   management   married   tertiary      no      395     yes   no   cellular       155         3     -1         0  unknown   no
# 49    32   management   married   tertiary      no     2349      no   no   cellular       134         5     -1         0  unknown   no
# 50    34   management   married   tertiary      no      415      no  yes   cellular       361         2     -1         0  unknown   no
# 51    46   management   married  secondary      no    12186      no   no    unknown        29         3     -1         0  unknown   no
# 52    41   management   married   tertiary      no       49     yes   no   cellular       312         5     -1         0  unknown   no
# 53    47   management   married   tertiary      no     3681      no   no   cellular       101         2     -1         0  unknown   no
# 54    29   management   married   tertiary      no      451      no   no   cellular       451         1     -1         0  unknown   no
# 55    56   management   married    unknown      no      353      no  yes   cellular       171         2     -1         0  unknown   no
# 56    35   management   married   tertiary      no     4286     yes   no    unknown       357         1     -1         0  unknown   no
# 57    55   management   married    unknown      no      559      no   no   cellular       271         2     -1         0  unknown   no
# 58    43   management   married   tertiary      no        2      no  yes   cellular       472         2     -1         0  unknown   no
# 59    38   management   married   tertiary      no     1199      no   no   cellular       178         1      1         1  success  yes
# 60    30   management    single   tertiary      no      424      no   no   cellular       298         4     -1         0  unknown  yes
# 61    47   management  divorced   tertiary      no      447      no  yes    unknown       126         1     -1         0  unknown   no
# 62    33   management    single   tertiary      no     1410     yes   no   cellular         8         1    254         5  failure   no
# 63    41   management   married   tertiary      no      832     yes  yes   cellular       164         1    176         1  failure   no
# 64    60   management    single   tertiary      no        0      no  yes   cellular       151         1     -1         0  unknown   no
# 65    37   management    single    unknown      no      504     yes   no   cellular       555         1     -1         0  unknown   no
# 66    57   management   married   tertiary      no     1602      no   no   cellular       339         3     -1         0  unknown   no
# 67    55   management   married    primary      no     2587      no   no   cellular       328         2     94         2  success  yes
# 68    35   management   married   tertiary     yes       32     yes   no   cellular       180         1     -1         0  unknown   no
# 69    39   management   married   tertiary      no      278      no  yes   cellular        60         3     -1         0  unknown   no
# 70    50   management   married   tertiary      no        4      no   no   cellular       223         1     96         2  failure   no
# 71    29   management   married   tertiary      no      318     yes   no   cellular      1434         2    356         4  failure   no
# 72    27   management    single    unknown      no     3196      no   no   cellular        10         2     -1         0  unknown   no
# 73    36   management    single   tertiary      no      339      no   no   cellular         6         6     -1         0  unknown   no
# 74    45   management   married   tertiary      no     5450      no   no   cellular       188         2     -1         0  unknown   no
# 75    32   management    single   tertiary      no     8436     yes   no   cellular       245         1    149         2  failure   no
# 76    40   management   married    primary      no      733     yes   no    unknown        94         7     -1         0  unknown   no
# 77    37   management   married   tertiary      no      393     yes   no   cellular       567         3    275         4  failure  yes
# 78    48   management   married   tertiary      no     6613      no   no    unknown       159         3     -1         0  unknown   no
# 79    33   management    single   tertiary      no     1240     yes   no   cellular       505         2    260         1    other   no
# 80    44   management   married  secondary      no      438     yes   no  telephone        37         3    303         1  failure   no
# 81    49   management   married   tertiary      no      322      no   no   cellular        72         4     -1         0  unknown   no
# 82    42   management   married   tertiary      no        0      no   no   cellular       325         2     -1         0  unknown   no
# 83    49   management  divorced   tertiary      no      755      no   no   cellular      1212         4     -1         0  unknown  yes
# 84    37   management   married   tertiary      no      502     yes   no   cellular       551         1    351         1  failure   no
# 85    37   management    single   tertiary      no      876     yes   no   cellular       140         4    327         2  failure   no
# 86    40   management   married   tertiary      no      542     yes   no   cellular      1816         1     -1         0  unknown   no
# 87    53   management   married    primary      no      995      no   no   cellular       200         3     -1         0  unknown   no
# 88    29   management   married   tertiary      no       20     yes   no   cellular       418         1     -1         0  unknown   no
# 89    56   management   married   tertiary      no      217      no  yes   cellular       121         2     -1         0  unknown   no
# 90    36   management   married  secondary      no      644     yes   no   cellular        54         2     -1         0  unknown   no
# 91    44   management   married   tertiary      no       22     yes   no   cellular       265         2     -1         0  unknown   no
# 92    30   management   married   tertiary      no     1221     yes   no  telephone       279         4     -1         0  unknown  yes
# 93    44   management   married   tertiary      no      795      no   no   cellular        99        24     -1         0  unknown   no
# 94    43   management  divorced   tertiary      no       36      no   no   cellular       118         1    102         2  failure   no
# 95    45   management  divorced   tertiary      no        0      no   no    unknown         5         1     -1         0  unknown   no
# 96    39   management   married   tertiary      no     -606     yes   no    unknown       142         1     -1         0  unknown   no
# 97    40   management    single  secondary      no    10378     yes   no   cellular       523         3     -1         0  unknown   no
# 98    40   management   married   tertiary      no     8969     yes   no   cellular       153         1     -1         0  unknown   no
# 99    41   management   married   tertiary      no      666     yes   no    unknown       253         3     -1         0  unknown   no
# 100   37   management    single    unknown      no      715     yes   no    unknown       247         2     -1         0  unknown   no
# 101   56   management    single  secondary      no      237     yes   no  telephone       236         4     -1         0  unknown   no
# 102   40   management   married   tertiary      no        0      no   no   cellular       109         8     -1         0  unknown   no
# 103   54   management   married   tertiary      no       55     yes   no   cellular       112         2     -1         0  unknown   no
# 104   33   management   married   tertiary      no      641     yes   no   cellular       347         2     -1         0  unknown   no
# 105   48   management  divorced   tertiary      no     1328     yes   no    unknown       339         1     -1         0  unknown   no
# 106   42   management    single   tertiary      no      515     yes   no   cellular       501         2     -1         0  unknown   no
# 107   32   management    single   tertiary      no    12607      no   no   cellular       203         5     84         1  failure   no
# 108   31   management   married   tertiary      no       13      no   no   cellular       110         5     -1         0  unknown   no
# 109   41   management   married   tertiary      no     3872      no   no   cellular       231         1     -1         0  unknown   no
# 110   32   management   married   tertiary      no      820     yes   no   cellular       738         3     -1         0  unknown   no
# 111   48   management  divorced   tertiary      no      108     yes   no    unknown        89         2     -1         0  unknown   no
# 112   36   management   married   tertiary      no     -381     yes   no   cellular        30        29     -1         0  unknown   no
# 113   34   management   married   tertiary      no      902     yes   no   cellular       159         1    367         2    other   no
# 114   40   management   married   tertiary      no     1584     yes   no  telephone       661         1     -1         0  unknown   no
# 115   58   management   married    primary      no       76     yes   no  telephone        54         4     -1         0  unknown   no
# 116   45   management   married   tertiary      no     1529      no   no   cellular       160         1     -1         0  unknown   no
# 117   26   management    single  secondary      no       63      no   no   cellular        76         4     -1         0  unknown   no
# 118   54   management   married   tertiary      no        0      no   no   cellular       118         5     -1         0  unknown   no
# 119   39   management    single   tertiary      no    12437      no   no  telephone        40         1     -1         0  unknown   no
# 120   43   management    single   tertiary      no     1304      no   no   cellular       501         2     -1         0  unknown  yes
# 121   36   management  divorced   tertiary      no     3611     yes   no    unknown       347         3     -1         0  unknown   no
# 122   53   management   married   tertiary      no     1319     yes   no   cellular       427         1    150         1  failure   no
# 123   38   management   married   tertiary      no     -558     yes   no   cellular       533         1     -1         0  unknown   no
# 124   29   management   married   tertiary      no      361     yes  yes   cellular       819         3     -1         0  unknown   no
# 125   33   management    single   tertiary      no      -53      no   no   cellular       617         2     -1         0  unknown   no
# 126   43   management  divorced   tertiary      no       38     yes   no   cellular       197         6     -1         0  unknown   no
# 127   28   management    single   tertiary      no      231     yes  yes   cellular       568         2     -1         0  unknown   no
# 128   31   management    single  secondary      no       36      no   no   cellular       105         2     -1         0  unknown   no
# 129   40   management    single   tertiary      no     1509      no   no   cellular       333         1     58         3  failure   no
# 130   33   management    single   tertiary      no     9449     yes   no   cellular       428         1     -1         0  unknown   no
# 131   59   management   married   tertiary      no     2764      no   no   cellular       237         1    206         2  failure   no
# 132   30   management    single   tertiary      no        2     yes  yes   cellular      1031         8     -1         0  unknown  yes
# 133   33   management  divorced   tertiary     yes      280      no  yes   cellular       155         1     -1         0  unknown   no
# 134   27   management    single   tertiary      no      703     yes   no    unknown       590         3     -1         0  unknown  yes
# 135   39   management   married   tertiary      no     2763     yes   no    unknown       526         2     -1         0  unknown  yes
# 136   46   management  divorced   tertiary      no     6269     yes   no  telephone       249         3    112         2  failure   no
# 137   60   management   married    primary      no      252     yes  yes   cellular       123         2    147         3  failure   no
# 138   40   management   married   tertiary      no     -117     yes   no   cellular       770         2     -1         0  unknown   no
# 139   28   management    single   tertiary      no        0     yes   no   cellular       767         5     -1         0  unknown  yes
# 140   32   management   married   tertiary      no        0      no   no   cellular        66         1     -1         0  unknown   no
# 141   55   management   married    primary      no      621      no  yes   cellular       114         1    208         1  failure   no
# 142   33   management   married   tertiary      no     1808     yes   no    unknown        99         4     -1         0  unknown   no
# 143   58   management    single   tertiary      no        2     yes   no  telephone       168         3     -1         0  unknown   no
# 144   47   management   married   tertiary      no     7708     yes   no   cellular       157         5     -1         0  unknown   no
# 145   80   management   married    primary      no     6483      no   no  telephone       123         1     -1         0  unknown   no
# 146   49   management   married   tertiary      no     1430      no   no   cellular       231         2     -1         0  unknown   no
# 147   32   management  divorced   tertiary      no      874      no   no   cellular      1282         6     -1         0  unknown  yes
# 148   56   management    single   tertiary      no    15311      no   no   cellular       157         6     -1         0  unknown   no
# 149   40   management   married   tertiary      no    10786      no   no    unknown       111         3     -1         0  unknown   no
# 150   32   management   married   tertiary      no       55      no   no   cellular       124         3     -1         0  unknown   no
# 151   31   management   married   tertiary      no     1010     yes   no   cellular       385         3    364         9    other   no
# 152   37   management    single   tertiary      no      509     yes   no   cellular       133         1     -1         0  unknown   no
# 153   47   management    single   tertiary      no      153     yes   no   cellular       192         2     -1         0  unknown   no
# 154   50   management   married   tertiary      no     3463      no  yes   cellular        96         1     -1         0  unknown  yes
# 155   57   management   married   tertiary      no     3250      no   no   cellular       162         3     -1         0  unknown   no
# 156   28   management    single  secondary      no     1633      no   no   cellular       275         1     -1         0  unknown  yes
# 157   33   management   married   tertiary      no     4020     yes  yes   cellular       251         1     -1         0  unknown   no
# 158   53   management   married  secondary      no       66      no  yes  telephone       141         1     -1         0  unknown   no
# 159   48   management   married   tertiary      no     1167     yes  yes   cellular       264         1     -1         0  unknown  yes
# 160   32   management    single   tertiary      no     1831     yes   no   cellular        86         2     -1         0  unknown   no
# 161   37   management  divorced  secondary      no      414      no   no   cellular       293         2    162         4  failure   no
# 162   57   management   married    primary      no     1052     yes   no    unknown       227         4     -1         0  unknown   no
# 163   52   management   married   tertiary      no     1944     yes   no   cellular       238         3    323         2  failure   no
# 164   26   management    single   tertiary      no      350      no   no   cellular       367         1     -1         0  unknown   no
# 165   37   management  divorced   tertiary      no      168     yes   no    unknown       227         1     -1         0  unknown   no
# 166   37   management   married   tertiary      no      865     yes   no   cellular       101         1     -1         0  unknown   no
# 167   51   management  divorced   tertiary      no        0      no   no   cellular        60         2     -1         0  unknown   no
# 168   34   management    single   tertiary      no     4348     yes   no   cellular       373         8     -1         0  unknown   no
# 169   41   management   married   tertiary      no     3016     yes   no   cellular        80         3     -1         0  unknown   no
# 170   49   management  divorced   tertiary      no     1405      no   no    unknown        29         1     -1         0  unknown   no
# 171   30   management    single   tertiary      no      162     yes   no    unknown       186         4     -1         0  unknown   no
# 172   58   management   married  secondary      no      111      no   no  telephone        58         2     -1         0  unknown   no
# 173   50   management   married   tertiary      no     2881      no   no   cellular       510         2      2         5    other   no
# 174   40   management   married  secondary      no      643     yes   no   cellular        74         2    256         1  failure   no
# 175   40   management   married   tertiary      no    -1212     yes   no   cellular      1259         2    333        18  failure   no
# 176   34   management   married   tertiary      no      703     yes   no   cellular       342         1     -1         0  unknown  yes
# 177   31   management   married  secondary      no      466     yes   no   cellular       164         1     -1         0  unknown   no
# 178   50   management   married  secondary     yes      421      no   no   cellular        22         5     -1         0  unknown   no
# 179   31   management    single   tertiary      no      112     yes   no   cellular       159         2    271         1  failure   no
# 180   43   management   married   tertiary      no     1429     yes   no   cellular      1015         1    198         2    other  yes
# 181   35   management    single   tertiary      no      714     yes   no   cellular       135        22     -1         0  unknown   no
# 182   42   management    single   tertiary      no        0      no   no   cellular        99         1     -1         0  unknown   no
# 183   59   management    single  secondary      no      671     yes  yes   cellular       219         2    259         5  failure   no
# 184   33   management   married   tertiary      no      148      no   no    unknown       717         1     -1         0  unknown   no
# 185   36   management   married  secondary      no     -148      no   no   cellular       144         2     -1         0  unknown   no
# 186   42   management   married  secondary      no     -105     yes   no   cellular        60         2     -1         0  unknown   no
# 187   46   management  divorced   tertiary      no      624      no   no   cellular       336         2    183         2  success  yes
# 188   48   management   married   tertiary      no      866      no   no   cellular       146         2     -1         0  unknown   no
# 189   43   management   married    primary      no     8167     yes   no    unknown       114         2     -1         0  unknown   no
# 190   38   management    single   tertiary      no    15030     yes   no   cellular       167         1    174         7    other   no
# 191   30   management    single   tertiary      no    19358      no   no   cellular       258         2     -1         0  unknown   no
# 192   48   management   married    primary      no      606      no   no   cellular        77         6     -1         0  unknown   no
# 193   36   management   married   tertiary      no     9269     yes  yes   cellular       107         2     -1         0  unknown   no
# 194   28   management    single   tertiary      no      882      no  yes   cellular        94         1    205         2  failure   no
# 195   49   management    single  secondary      no       61     yes   no   cellular       185         2    246         1  failure   no
# 196   45   management   married   tertiary      no     -459      no   no   cellular       508         6     -1         0  unknown   no
# 197   40   management   married   tertiary      no       60      no   no    unknown       172         6     -1         0  unknown   no
# 198   41   management   married   tertiary      no      -29      no   no   cellular        41         2    266         2  failure   no
# 199   33   management   married  secondary      no     4040     yes   no   cellular       132         2     -1         0  unknown   no
# 200   34   management   married   tertiary      no      136     yes   no   cellular       156         1     -1         0  unknown   no
# 201   39   management  divorced   tertiary      no     3575      no  yes   cellular        74         3     -1         0  unknown   no
# 202   39   management   married  secondary      no     1072     yes   no    unknown      1168         2     -1         0  unknown   no
# 203   31   management   married   tertiary      no     8312      no   no   cellular        43        13     -1         0  unknown   no
# 204   34   management   married   tertiary      no        0     yes   no   cellular       262         1     99         2  success  yes
# 205   36   management   married   tertiary      no      222     yes   no   cellular       317         1    169         2  failure   no
# 206   52   management   married   tertiary      no     3163      no   no   cellular        56         6     -1         0  unknown   no
# 207   33   management  divorced  secondary      no      106      no   no   cellular       175         3     -1         0  unknown   no
# 208   55   management   married   tertiary      no      979      no  yes   cellular       123         1     -1         0  unknown   no
# 209   34   management    single   tertiary      no       84      no   no   cellular       231         1     -1         0  unknown   no
# 210   39   management    single   tertiary      no      816     yes   no   cellular        37         3     -1         0  unknown   no
# 211   55   management  divorced    unknown      no        2     yes   no    unknown        95         1     -1         0  unknown   no
# 212   53   management  divorced    primary      no      255      no   no   cellular       126         1     -1         0  unknown   no
# 213   33   management    single   tertiary      no     3143      no   no   cellular       421         2     -1         0  unknown  yes
# 214   33   management    single   tertiary      no     1909      no   no   cellular       191         2     -1         0  unknown   no
# 215   43   management  divorced   tertiary      no      388     yes   no    unknown      2087         2     -1         0  unknown  yes
# 216   56   management  divorced   tertiary      no     1016     yes   no    unknown       184         5     -1         0  unknown   no
# 217   42   management    single   tertiary      no      525      no   no   cellular       127         2     -1         0  unknown   no
# 218   46   management   married   tertiary      no      964     yes   no   cellular       174         1     -1         0  unknown   no
# 219   58   management   married  secondary      no       37      no   no   cellular        84        11     -1         0  unknown   no
# 220   34   management    single   tertiary      no      673     yes  yes   cellular       271         1    184         1  failure   no
# 221   41   management   married   tertiary      no    10758     yes   no   cellular       288         1     -1         0  unknown   no
# 222   40   management   married   tertiary      no        5     yes   no   cellular       219         3     -1         0  unknown   no
# 223   36   management   married   tertiary      no      605     yes   no    unknown       204         1     -1         0  unknown   no
# 224   53   management   married   tertiary      no        4      no   no    unknown        19         6     -1         0  unknown   no
# 225   34   management   married   tertiary      no        8      no   no   cellular       169         4     -1         0  unknown   no
# 226   38   management   married   tertiary      no      -70     yes   no   cellular       140         1      2         3    other   no
# 227   46   management    single    primary      no      538      no   no    unknown       118         3     -1         0  unknown   no
# 228   43   management   married   tertiary      no     2767     yes   no    unknown       317         7     -1         0  unknown   no
# 229   41   management   married   tertiary      no      176     yes  yes    unknown        42         1     -1         0  unknown   no
# 230   42   management    single  secondary      no     9720      no   no   cellular        81         2     -1         0  unknown   no
# 231   58   management   married   tertiary      no      299      no   no   cellular       120         4     -1         0  unknown   no
# 232   36   management    single   tertiary      no     3343      no   no   cellular       307         1     -1         0  unknown   no
# 233   23   management    single   tertiary      no      736     yes   no   cellular       119         1     -1         0  unknown   no
# 234   32   management   married   tertiary      no     1390      no   no   cellular       116         2     -1         0  unknown   no
# 235   48   management   married   tertiary      no     1147      no   no   cellular       389         1     64         2  success  yes
# 236   44   management   married  secondary      no     8262     yes   no   cellular       201        16     -1         0  unknown   no
# 237   30   management    single   tertiary      no      726     yes   no   cellular        39         1    342         3  failure   no
# 238   39   management    single   tertiary      no      416      no   no   cellular        56         4     -1         0  unknown   no
# 239   30   management    single   tertiary      no     -218     yes   no   cellular        13        15     -1         0  unknown   no
# 240   45   management  divorced   tertiary      no     2096      no   no   cellular       127         1    100         2  failure   no
# 241   59   management   married   tertiary      no     1831      no   no   cellular       122         1     92         1  failure   no
# 242   28   management   married   tertiary      no     1480     yes   no   cellular       143         1     -1         0  unknown   no
# 243   48   management   married   tertiary      no     7289     yes   no   cellular       316         3     -1         0  unknown   no
# 244   41   management   married   tertiary      no     2885      no   no   cellular        40         1     -1         0  unknown   no
# 245   43   management    single   tertiary      no      146      no   no   cellular        50         1    113         5    other   no
# 246   28   management   married   tertiary      no      318     yes   no    unknown         4         4     -1         0  unknown   no
# 247   28   management    single   tertiary      no     4937     yes   no  telephone       421         3     -1         0  unknown   no
# 248   32   management    single    unknown      no      787      no   no   cellular        92         1     -1         0  unknown   no
# 249   36   management    single   tertiary      no      243     yes   no   cellular       160         2    360         3  failure   no
# 250   29   management   married   tertiary      no      877      no   no   cellular       166         3     -1         0  unknown   no
# 251   41   management  divorced   tertiary      no     4567     yes  yes   cellular       106         1     -1         0  unknown   no
# 252   36   management    single   tertiary      no     3875     yes   no    unknown        21         5     -1         0  unknown   no
# 253   60   management  divorced   tertiary      no      366      no   no   cellular       593         1     -1         0  unknown  yes
# 254   48   management   married   tertiary      no      998     yes   no   cellular       121         3     -1         0  unknown   no
# 255   39   management   married   tertiary      no      246      no   no   cellular        86         2     -1         0  unknown   no
# 256   27   management    single   tertiary      no      446      no   no   cellular       205         3     -1         0  unknown   no
# 257   41   management  divorced   tertiary      no      369     yes   no  telephone         9         3     -1         0  unknown   no
# 258   38   management    single   tertiary      no     1373      no   no   cellular       119         4     -1         0  unknown   no
# 259   31   management    single   tertiary      no       62     yes   no   cellular       175         1    293         5  failure   no
# 260   33   management   married   tertiary      no      273     yes   no    unknown       803         1     -1         0  unknown  yes
# 261   58   management   married   tertiary      no     2729      no   no    unknown       188         1     -1         0  unknown   no
# 262   35   management   married   tertiary      no      317     yes   no    unknown       162         3     -1         0  unknown   no
# 263   50   management   married   tertiary      no     -470     yes   no   cellular       506         2    170         3  failure   no
# 264   37   management   married   tertiary      no     5106      no   no   cellular       244         1     -1         0  unknown  yes
# 265   38   management   married   tertiary      no      126     yes   no    unknown       164         2     -1         0  unknown   no
# 266   36   management   married  secondary      no     1825     yes   no   cellular        24         1    346         1  failure   no
# 267   64   management   married   tertiary      no      679      no   no  telephone       135         3     -1         0  unknown   no
# 268   35   management    single   tertiary      no     2988     yes   no   cellular       179         1     -1         0  unknown   no
# 269   61   management   married   tertiary      no     6016      no   no   cellular       670         3     -1         0  unknown  yes
# 270   28   management   married   tertiary      no     3694      no  yes   cellular        70         2     -1         0  unknown   no
# 271   36   management    single   tertiary      no      490      no   no   cellular       207         8     98         1  failure  yes
# 272   29   management    single   tertiary      no    15459      no   no   cellular       245         3     97         7  success   no
# 273   49   management  divorced   tertiary      no     2370     yes  yes    unknown        56         1    103         2    other   no
# 274   35   management   married   tertiary      no        8     yes   no    unknown        55         4     -1         0  unknown   no
# 275   47   management   married   tertiary      no      109     yes   no   cellular       268         1     -1         0  unknown   no
# 276   52   management   married   tertiary      no      -11     yes   no   cellular        94         4     -1         0  unknown   no
# 277   33   management  divorced  secondary      no     1897     yes  yes    unknown       197         1     -1         0  unknown   no
# 278   41   management  divorced   tertiary      no     5037      no   no   cellular       252         9    185         5    other  yes
# 279   32   management   married   tertiary      no      913     yes   no   cellular       883         1    674         4  failure   no
# 280   32   management    single   tertiary      no     1218     yes   no  telephone        70         2     -1         0  unknown   no
# 281   31   management   married   tertiary      no     2603     yes   no   cellular       280         4     -1         0  unknown  yes
# 282   46   management  divorced   tertiary      no      743      no   no    unknown        36         2     -1         0  unknown   no
# 283   24   management    single   tertiary      no      172      no   no   cellular        67         2     -1         0  unknown   no
# 284   32   management    single   tertiary      no       41      no   no   cellular       686         5     -1         0  unknown  yes
# 285   30   management    single   tertiary      no      329     yes   no    unknown       122        16     -1         0  unknown   no
# 286   42   management   married    unknown      no     1519      no   no   cellular       230         1     92         1  success  yes
# 287   31   management   married  secondary      no      625     yes   no   cellular       424         1    138         1  failure   no
# 288   32   management    single   tertiary      no      151     yes   no    unknown       118         1     -1         0  unknown   no
# 289   30   management   married   tertiary      no     3134     yes   no   cellular       124         1     -1         0  unknown   no
# 290   49   management   married  secondary      no     1623     yes   no   cellular      1081         2     -1         0  unknown  yes
# 291   48   management   married   tertiary      no       60      no   no  telephone       376         2    339         7  failure   no
# 292   28   management    single   tertiary      no     1027     yes   no   cellular       433         1     -1         0  unknown   no
# 293   26   management    single   tertiary      no      205      no   no    unknown       111         1     -1         0  unknown   no
# 294   32   management    single   tertiary      no      311      no   no    unknown       757         2     -1         0  unknown  yes
# 295   40   management    single   tertiary      no     1509      no   no   cellular       144         2    124         1  failure   no
# 296   28   management    single  secondary      no      171      no   no   cellular        93         1     -1         0  unknown  yes
# 297   40   management  divorced   tertiary      no       69     yes   no   cellular       503         2    280         2  failure   no
# 298   36   management   married   tertiary      no       61      no  yes   cellular       452         2     -1         0  unknown   no
# 299   43   management  divorced   tertiary      no       99      no   no   cellular        24         3     -1         0  unknown   no
# 300   30   management    single   tertiary      no      604      no  yes   cellular       475         1     -1         0  unknown   no
# 301   34   management   married   tertiary      no     1906     yes   no   cellular        68         3     -1         0  unknown   no
# 302   36   management   married   tertiary      no     -296     yes   no   cellular       113         3     -1         0  unknown   no
# 303   28   management    single   tertiary      no     1466     yes   no   cellular        40         1     -1         0  unknown   no
# 304   34   management   married   tertiary      no     4170     yes   no    unknown       935         1     -1         0  unknown   no
# 305   25   management    single   tertiary      no      553     yes   no   cellular       113         4    479         1  failure   no
# 306   50   management   married   tertiary      no       85      no  yes   cellular       141         1     -1         0  unknown   no
# 307   44   management   married    unknown      no      415     yes   no  telephone         7         7     -1         0  unknown   no
# 308   48   management  divorced   tertiary      no      507     yes   no   cellular       528         1     -1         0  unknown   no
# 309   50   management   married   tertiary      no        0      no   no   cellular       243         5     -1         0  unknown   no
# 310   34   management    single   tertiary      no     1171     yes   no   cellular       129         1     -1         0  unknown   no
# 311   36   management   married   tertiary      no      495      no   no   cellular       157         3     97         2  success  yes
# 312   31   management   married   tertiary      no     1224     yes  yes   cellular      1441         2     -1         0  unknown  yes
# 313   33   management   married   tertiary      no     3696      no   no   cellular       305         1    182         3  failure   no
# 314   36   management   married   tertiary      no     2987     yes   no   cellular       307         1     -1         0  unknown  yes
# 315   38   management   married   tertiary      no        0     yes   no   cellular       537         5    303         2  failure   no
# 316   57   management   married   tertiary      no     1172      no   no    unknown        26         1     -1         0  unknown   no
# 317   40   management    single  secondary      no      192     yes   no    unknown        71        11     -1         0  unknown   no
# 318   46   management   married   tertiary      no     1008      no   no   cellular        24        13     -1         0  unknown   no
# 319   50   management   married   tertiary      no      -94      no  yes    unknown        75         1     -1         0  unknown   no
# 320   40   management   married   tertiary      no       -7      no  yes  telephone       697         1     -1         0  unknown   no
# 321   35   management   married   tertiary      no       93      no   no   cellular       198         2     88         1    other   no
# 322   29   management    single  secondary      no      417      no   no   cellular        90         1     -1         0  unknown   no
# 323   54   management  divorced   tertiary      no     2171     yes  yes  telephone      1034         1     -1         0  unknown  yes
# 324   43   management   married   tertiary      no      690     yes   no   cellular       171         3     -1         0  unknown   no
# 325   35   management   married   tertiary      no     1100      no  yes   cellular       127         2     -1         0  unknown   no
# 326   33   management    single   tertiary      no     1998      no   no   cellular       570         1     -1         0  unknown   no
# 327   55   management   married    primary      no      229      no  yes    unknown       175         3     -1         0  unknown   no
# 328   52   management   married   tertiary      no     1339     yes   no   cellular       343         5     -1         0  unknown   no
# 329   51   management   married   tertiary      no     2934     yes   no   cellular       727         4     -1         0  unknown   no
# 330   34   management   married   tertiary      no      176      no   no   cellular        61         4     -1         0  unknown   no
# 331   42   management  divorced    unknown      no     7702      no   no   cellular       138         2     -1         0  unknown  yes
# 332   48   management   married  secondary      no      117     yes   no   cellular       635         1     -1         0  unknown   no
# 333   40   management   married   tertiary      no     1041     yes   no    unknown        73         1     -1         0  unknown   no
# 334   37   management   married   tertiary      no      539      no   no   cellular       540         2    115         3  failure   no
# 335   42   management    single   tertiary      no      100      no   no   cellular        64         2     -1         0  unknown   no
# 336   37   management    single   tertiary      no      815     yes   no   cellular        77         1     -1         0  unknown   no
# 337   32   management   married  secondary      no     6217     yes  yes   cellular       486         2    181         2  failure   no
# 338   49   management    single   tertiary      no      151     yes   no   cellular        97         3     -1         0  unknown  yes
# 339   47   management  divorced   tertiary      no     1149      no  yes   cellular        82         2     -1         0  unknown   no
# 340   33   management    single  secondary      no     8004      no   no   cellular       414         3     -1         0  unknown   no
# 341   46   management  divorced   tertiary      no     1297      no   no   cellular       716         3     -1         0  unknown  yes
# 342   29   management  divorced   tertiary      no      415     yes  yes    unknown       449         4     -1         0  unknown   no
# 343   34   management   married   tertiary      no      417     yes   no   cellular       138         1     -1         0  unknown   no
# 344   43   management   married   tertiary      no     1188      no   no   cellular       140         2     -1         0  unknown   no
# 345   32   management  divorced   tertiary      no        1     yes   no    unknown       399         4     -1         0  unknown   no
# 346   39   management   married   tertiary      no       12     yes   no    unknown       130         1     -1         0  unknown   no
# 347   33   management  divorced   tertiary      no        0      no   no   cellular       305         2     -1         0  unknown   no
# 348   30   management   married   tertiary      no        0     yes   no   cellular       127         1     -1         0  unknown   no
# 349   32   management   married   tertiary      no       71     yes   no   cellular       221         8     -1         0  unknown   no
# 350   32   management   married   tertiary      no     4761     yes   no   cellular       159         2    350         2  failure   no
# 351   66   management   married   tertiary      no     1048     yes   no   cellular       971         2     -1         0  unknown   no
# 352   28   management    single   tertiary      no     3238     yes   no    unknown         7         1     -1         0  unknown   no
# 353   42   management  divorced   tertiary      no        0      no   no    unknown        85         2     -1         0  unknown   no
# ...
# 882   35   management   married   tertiary      no        0     yes   no   cellular       295         3     -1         0  unknown   no
# 883   36   management    single   tertiary      no      876     yes   no    unknown       241         2     -1         0  unknown   no
# 884   30   management   married   tertiary      no      944      no   no   cellular       251         2     -1         0  unknown  yes
# 885   33   management    single   tertiary      no       71      no   no   cellular       107         6     -1         0  unknown   no
# 886   34   management   married   tertiary      no      436     yes   no   cellular        28         1    345         1  failure   no
# 887   31   management   married   tertiary      no     1170      no   no   cellular       200         4     -1         0  unknown   no
# 888   46   management  divorced   tertiary      no       25      no   no    unknown       103         2     -1         0  unknown   no
# 889   55   management   married   tertiary      no      236      no   no   cellular       200         1     -1         0  unknown   no
# 890   34   management   married   tertiary      no     -308     yes   no   cellular       140         2     -1         0  unknown   no
# 891   32   management    single   tertiary      no      473     yes   no   cellular        72         2    361         1    other   no
# 892   34   management   married   tertiary      no     4831     yes   no   cellular       265         1     -1         0  unknown   no
# 893   30   management   married  secondary      no        0     yes   no   cellular       756         3     -1         0  unknown   no
# 894   31   management   married   tertiary      no      430     yes   no   cellular       137        16     -1         0  unknown   no
# 895   37   management   married   tertiary      no        0      no   no   cellular       129         4    107         2  failure   no
# 896   49   management   married   tertiary      no       92     yes   no    unknown       221         2     -1         0  unknown   no
# 897   59   management   married   tertiary      no     1881      no   no   cellular       456         2     -1         0  unknown   no
# 898   42   management    single   tertiary      no    10907      no   no   cellular        74         3     -1         0  unknown   no
# 899   57   management   married   tertiary      no     1341     yes   no    unknown       339         2     -1         0  unknown   no
# 900   47   management   married   tertiary      no     6637     yes   no   cellular       174         2     -1         0  unknown   no
# 901   31   management   married   tertiary      no      271      no   no   cellular        89         1     -1         0  unknown   no
# 902   31   management    single   tertiary      no     1130     yes   no   cellular       224         3     74         4  failure   no
# 903   29   management    single  secondary      no      584     yes   no    unknown       541        19     -1         0  unknown   no
# 904   34   management   married   tertiary      no      606      no   no   cellular        97         1     -1         0  unknown  yes
# 905   49   management    single    primary      no      548      no   no  telephone       115         6     -1         0  unknown   no
# 906   37   management   married   tertiary      no     1689     yes   no    unknown       645         2     -1         0  unknown   no
# 907   48   management   married   tertiary      no     5057      no  yes   cellular        37         1     -1         0  unknown   no
# 908   45   management  divorced   tertiary      no      220     yes   no    unknown        89         4     -1         0  unknown   no
# 909   37   management   married   tertiary      no     4039      no  yes   cellular       106         2     -1         0  unknown   no
# 910   31   management   married   tertiary      no      582     yes   no   cellular        58         2     -1         0  unknown   no
# 911   44   management    single   tertiary      no     1424     yes   no   cellular       201         2     -1         0  unknown   no
# 912   34   management   married   tertiary      no      997     yes  yes   cellular        81         1     -1         0  unknown   no
# 913   41   management   married   tertiary      no     6563      no   no   cellular       136         8     -1         0  unknown   no
# 914   32   management    single   tertiary      no        0      no   no   cellular         9         6     -1         0  unknown   no
# 915   32   management    single   tertiary      no        2     yes   no   cellular       100         2     -1         0  unknown  yes
# 916   33   management    single   tertiary      no      201     yes   no   cellular       171         1    183         1  failure   no
# 917   35   management   married   tertiary      no     3161      no   no   cellular       433         2     -1         0  unknown   no
# 918   42   management   married  secondary      no     1331      no   no   cellular       698         2     -1         0  unknown   no
# 919   29   management    single   tertiary      no     5980     yes   no    unknown       317         1     -1         0  unknown   no
# 920   37   management  divorced   tertiary      no      896      no  yes   cellular       343         2     -1         0  unknown   no
# 921   40   management   married  secondary      no       99      no   no   cellular        15         5     -1         0  unknown   no
# 922   53   management   married   tertiary      no       15      no   no   cellular       921         2     -1         0  unknown  yes
# 923   52   management   married  secondary      no      335      no   no   cellular       411         1    182         1  failure  yes
# 924   33   management   married   tertiary      no      752     yes   no   cellular       104         4     -1         0  unknown   no
# 925   36   management   married   tertiary      no     1852      no   no    unknown       362         1     -1         0  unknown   no
# 926   50   management  divorced   tertiary      no      100     yes  yes   cellular       157         1    299         3  failure   no
# 927   37   management    single   tertiary      no        9      no   no   cellular       484         2     -1         0  unknown   no
# 928   40   management    single   tertiary      no       36     yes   no    unknown       240         3     -1         0  unknown   no
# 929   48   management   married   tertiary      no      263     yes   no    unknown       350         2     -1         0  unknown   no
# 930   30   management    single   tertiary      no     2186     yes   no    unknown       366         1     -1         0  unknown   no
# 931   50   management   married   tertiary      no    19447     yes  yes   cellular       166         1     -1         0  unknown   no
# 932   39   management    single  secondary      no       36      no   no   cellular        70         2     -1         0  unknown   no
# 933   34   management    single   tertiary      no     -292     yes   no   cellular       181         6     -1         0  unknown   no
# 934   33   management   married   tertiary      no      296      no   no   cellular        90         2     -1         0  unknown   no
# 935   30   management   married   tertiary      no       42      no   no   cellular       115         6     -1         0  unknown   no
# 936   33   management   married   tertiary      no      150      no   no   cellular       151         2     -1         0  unknown   no
# 937   29   management    single   tertiary      no     4210     yes   no   cellular       119         1     -1         0  unknown   no
# 938   52   management    single   tertiary      no        4      no  yes   cellular        30         9     -1         0  unknown   no
# 939   39   management  divorced   tertiary      no      355     yes   no   cellular       313         5     -1         0  unknown   no
# 940   34   management   married   tertiary      no      436      no  yes   cellular       118         4     -1         0  unknown   no
# 941   31   management   married   tertiary      no     4945      no   no   cellular       445         1     -1         0  unknown   no
# 942   34   management    single   tertiary      no     2679     yes   no   cellular       195         1     -1         0  unknown   no
# 943   43   management   married   tertiary      no     3529     yes   no   cellular       190         3     -1         0  unknown   no
# 944   30   management    single   tertiary      no     7845     yes   no    unknown        59         1     -1         0  unknown   no
# 945   45   management    single   tertiary      no     2048     yes   no   cellular       310         1    804         1  failure  yes
# 946   34   management   married   tertiary      no     1557     yes  yes    unknown       213         1     -1         0  unknown   no
# 947   47   management   married   tertiary      no      295     yes   no   cellular       157         1     -1         0  unknown   no
# 948   32   management   married  secondary      no     3935     yes   no    unknown       129         2     -1         0  unknown   no
# 949   40   management   married   tertiary      no      -17     yes  yes   cellular       474         1    256         1  success  yes
# 950   44   management   married   tertiary      no     4460      no   no  telephone       168         2     -1         0  unknown   no
# 951   38   management   married   tertiary      no    12877      no   no    unknown       118         3     -1         0  unknown   no
# 952   28   management    single   tertiary      no        0      no   no  telephone       198         2     -1         0  unknown   no
# 953   55   management   married   tertiary      no     6880      no   no   cellular       353         2     -1         0  unknown   no
# 954   37   management    single   tertiary      no      102     yes   no   cellular       101         2     -1         0  unknown   no
# 955   37   management   married    primary      no     3953     yes   no   cellular       610         2    138         1  failure   no
# 956   29   management    single   tertiary      no      572      no   no   cellular       314         1    195         1  success  yes
# 957   38   management    single   tertiary      no      623      no   no   cellular       297         4    144         4    other  yes
# 958   61   management   married  secondary      no      967      no   no   cellular       180         1     -1         0  unknown   no
# 959   36   management  divorced   tertiary      no        0      no   no   cellular        81         4     -1         0  unknown   no
# 960   59   management   married    unknown      no     3534      no   no   cellular       216         4     -1         0  unknown   no
# 961   42   management   married   tertiary      no      603     yes   no   cellular       298         5     -1         0  unknown   no
# 962   32   management    single   tertiary      no      577      no   no   cellular       101         2     -1         0  unknown   no
# 963   43   management   married   tertiary      no        0     yes   no   cellular       110         1     -1         0  unknown   no
# 964   38   management   married   tertiary      no     3436      no   no   cellular       663         4     -1         0  unknown  yes
# 965   45   management   married   tertiary      no     6945      no   no   cellular       131         5    356         3  failure   no
# 966   48   management   married   tertiary      no     1175     yes   no  telephone      1476         3     -1         0  unknown   no
# 967   31   management   married   tertiary      no     1183     yes   no    unknown       676         6     -1         0  unknown   no
# 968   34   management   married   tertiary      no      297     yes   no   cellular        63         4     -1         0  unknown   no
# 969   59  blue-collar   married  secondary      no        0     yes   no    unknown       226         1     -1         0  unknown   no
# 970   31  blue-collar   married  secondary      no      360     yes  yes   cellular        89         1    241         1  failure   no
# 971   25  blue-collar    single    primary      no     -221     yes   no    unknown       250         1     -1         0  unknown   no
# 972   55  blue-collar   married    primary      no      627     yes   no    unknown       247         1     -1         0  unknown   no
# 973   32  blue-collar   married  secondary      no     2089     yes   no   cellular       132         1     -1         0  unknown  yes
# 974   52  blue-collar   married  secondary      no     1117     yes   no   cellular       365         1     -1         0  unknown   no
# 975   55  blue-collar   married    primary      no      145      no   no  telephone        59         3      5         2    other   no
# 976   26  blue-collar   married    primary      no        0     yes   no    unknown       425         1     -1         0  unknown   no
# 977   45  blue-collar  divorced    primary      no      844      no   no    unknown      1018         3     -1         0  unknown  yes
# 978   53  blue-collar   married  secondary      no     2231     yes   no   cellular       272         3     -1         0  unknown   no
# 979   41  blue-collar   married    primary      no     -516      no  yes  telephone       554         3     -1         0  unknown   no
# 980   51  blue-collar  divorced  secondary      no      203     yes   no   cellular       134         1    170         5  failure   no
# 981   41  blue-collar  divorced  secondary      no      174     yes   no   cellular       367         2    297         1    other   no
# 982   50  blue-collar  divorced    primary      no      388      no   no   cellular       701         1     -1         0  unknown   no
# 983   51  blue-collar   married    primary      no     1466     yes   no    unknown       406         2     -1         0  unknown   no
# 984   35  blue-collar    single    primary      no      293     yes   no    unknown       521         2     -1         0  unknown   no
# 985   34  blue-collar   married  secondary      no     1831     yes   no    unknown       203         2     -1         0  unknown   no
# 986   39  blue-collar   married    primary      no      111      no   no   cellular       201         2     -1         0  unknown   no
# 987   34  blue-collar   married    primary      no      455     yes   no    unknown       372         3     -1         0  unknown   no
# 988   57  blue-collar   married  secondary      no    14093      no   no   cellular       231         5     -1         0  unknown   no
# 989   36  blue-collar  divorced  secondary      no     2843      no   no   cellular       473         1    182         1  success   no
# 990   36  blue-collar   married  secondary      no        0     yes   no    unknown       337         1     -1         0  unknown   no
# 991   37  blue-collar   married  secondary      no      427     yes  yes    unknown       371         3     -1         0  unknown   no
# 992   33  blue-collar    single  secondary      no       22      no   no   cellular        76         2    207         1  failure   no
# 993   39  blue-collar   married    primary      no       52      no   no   cellular        69         1     -1         0  unknown   no
# 994   45  blue-collar   married    primary      no      419      no   no   cellular       113         4     -1         0  unknown   no
# 995   36  blue-collar   married  secondary      no     -231      no  yes   cellular       779         2     -1         0  unknown   no
# 996   32  blue-collar    single  secondary      no      228      no   no  telephone       176         1    288         3  failure   no
# 997   41  blue-collar   married    primary      no      168     yes   no   cellular       187         3     -1         0  unknown   no
# 998   37  blue-collar   married    primary      no        0     yes   no    unknown        24         1     -1         0  unknown   no
# 999   43  blue-collar   married    unknown     yes     -715     yes   no    unknown        67         3     -1         0  unknown   no
#
# [Showing only the first 1000 rows x 15 columns]

# %% [markdown]
# ## Part 3: Preparing Data for Training a Model
#
# What follows is something analagous to a dataloader pipeline in Tensorflow--we're going to chain together some transformations that will convert our categorical variables into a one-hot format more amenable to training a machine learning model.
# The next code cell just sets this all up, but it doesn't run these transformations on our data yet.

# %% [markdown]
# The process includes Category Indexing, One-Hot Encoding and VectorAssembler — a feature transformation that merges multiple columns into a vector column.

# %% [markdown]
# The code is taken from [databricks’ official site](https://docs.databricks.com/applications/machine-learning/train-model/mllib/index.html#binary-classification-example) and it indexes each categorical column using the StringIndexer, then converts the indexed categories into one-hot encoded variables.
# The resulting output has the binary vectors appended to the end of each row.
# We use the StringIndexer again to encode our labels to label indices.
# Next, we use the VectorAssembler to combine all the feature columns into a single vector column.

# %% [markdown]
# 1. Complete the code by completing the assignment of `assembler`. Use `VectorAssembler` and pass in `assemblerInputs` as `inputCols` and name the `outputCol` `"features"`.

# %%
from pyspark.ml.feature import OneHotEncoder , StringIndexer, VectorAssembler

categoricalColumns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'poutcome']
stages = []

for categoricalCol in categoricalColumns:
    stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'Index')
    encoder = OneHotEncoder(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
    stages += [stringIndexer, encoder]

label_stringIdx = StringIndexer(inputCol = 'y', outputCol = 'label')
stages += [label_stringIdx]
numericCols = ['age', 'balance', 'duration', 'campaign', 'pdays', 'previous']
assemblerInputs = [c + "classVec" for c in categoricalColumns] + numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]

# %% [markdown]
# ## Part 4: Pipeline

# %% [markdown]
# We use Pipeline to chain multiple transformations and estimators together to specify our machine learning workflow.
# A Pipeline’s stages are specified as an ordered array.
# To run the pipeline on our Pandas on Spark DataFrame, we will convert it back to a Spark DataFrame using the **`to_spark()`** command
#
# 1. Fit a pipeline on df.

# %%
from pyspark.ml import Pipeline
sdf = psdf.to_spark()
pipeline = Pipeline(stages=stages)

pipelineModel = pipeline.fit(sdf)
# Out:
# /usr/local/lib/python3.8/dist-packages/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `to_spark`, the existing index is lost when converting to Spark DataFrame.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %% [markdown]
# 2. Transform `pipelineModel` on `df` and assign this to variable `transformed_df`.

# %%
transformed_df = pipelineModel.transform(sdf)
transformed_df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)
#  |-- jobIndex: double (nullable = false)
#  |-- jobclassVec: vector (nullable = true)
#  |-- maritalIndex: double (nullable = false)
#  |-- maritalclassVec: vector (nullable = true)
#  |-- educationIndex: double (nullable = false)
#  |-- educationclassVec: vector (nullable = true)
#  |-- defaultIndex: double (nullable = false)
#  |-- defaultclassVec: vector (nullable = true)
#  |-- housingIndex: double (nullable = false)
#  |-- housingclassVec: vector (nullable = true)
#  |-- loanIndex: double (nullable = false)
#  |-- loanclassVec: vector (nullable = true)
#  |-- contactIndex: double (nullable = false)
#  |-- contactclassVec: vector (nullable = true)
#  |-- poutcomeIndex: double (nullable = false)
#  |-- poutcomeclassVec: vector (nullable = true)
#  |-- label: double (nullable = false)
#  |-- features: vector (nullable = true)

# %% [markdown]
# From the transformation, we'd like to take the `label` and `features` columns as well as the original columns from `sdf.`
#
# 3. Use the `.select()` method to pull these columns from the `transformed_df` and reassign the resulting DataFrame to `sdf`.

# %%
selectedCols = ['label', 'features'] + sdf.columns
sdf = transformed_df[selectedCols]
sdf.printSchema()
# Out:
# root
#  |-- label: double (nullable = false)
#  |-- features: vector (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)

# %% [markdown]
# 4. Let's view the first five rows of the `sdf` DataFrame using the methods we learned in Part 2:
#     * `.show()` method
#     * `.take()` method and convert result to a Pandas DataFrame

# %%
sdf.show(5)
new_df = pd.DataFrame(sdf.take(5), columns=sdf.columns)
# Out:
# +-----+--------------------+---+----------+--------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# |label|            features|age|       job| marital|education|default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|  y|
# +-----+--------------------+---+----------+--------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# |  0.0|(30,[0,12,14,16,1...| 35|management|  single| tertiary|     no|   1350|    yes|  no|cellular| 16|  apr|     185|       1|  330|       1| failure| no|
# |  0.0|(30,[0,11,14,16,1...| 30|management| married| tertiary|     no|   1476|    yes| yes| unknown|  3|  jun|     199|       4|   -1|       0| unknown| no|
# |  0.0|(30,[0,12,14,16,1...| 35|management|  single| tertiary|     no|    747|     no|  no|cellular| 23|  feb|     141|       2|  176|       3| failure| no|
# |  0.0|(30,[0,11,14,16,1...| 40|management| married| tertiary|     no|    194|     no| yes|cellular| 29|  aug|     189|       2|   -1|       0| unknown| no|
# |  0.0|(30,[0,16,17,18,1...| 38|management|divorced|  unknown|     no|      0|    yes|  no|cellular| 18|  nov|      96|       2|   -1|       0| unknown| no|
# +-----+--------------------+---+----------+--------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+
# only showing top 5 rows

# %% [markdown]
# 5. Randomly split the dataset in training and test sets, with 70% of the data in the training set and the remaining 30% in the test set.
#
#     Hint: Call the `.randomSplit()` method.

# %%
train, test = sdf.randomSplit([0.7,0.3])

# %% [markdown]
# 6. What are the sizes of the training and test sets?

# %%
print('train size: ', train.count(), ',', len(train.columns))
print('test size: ', test.count(), ',', len(test.columns))
# Out:
# train size:  3174 , 19
# test size:  1347 , 19

# %% [markdown]
# ## Part 5: Logistic Regression Model
#
# Optional:
# - You can build a RandomForestClassifier with : from pyspark.ml.classification import RandomForestClassifier
# - You can build a Gradient-Boosted Tree Classifier with : from pyspark.ml.classification import GBTClassifier
#
# 1. Fit a logistic regression with `featuresCol` as `"features"`, `labelCol` as `"label"` and a `maxIter` of 10.

# %%
from pyspark.ml.classification import LogisticRegression

lrModel = LogisticRegression().setParams(featuresCol="features", labelCol="label", maxIter=10).fit(train)

# %% [markdown]
# 2. We can obtain the coefficients by using logistic regression model’s attributes. Look at the following plot of the beta coefficients.

# %%
import matplotlib.pyplot as plt
import numpy as np
beta = np.sort(lrModel.coefficients)
plt.plot(beta)
plt.ylabel('Beta Coefficients')
plt.show()

# %% [markdown]
# 3. Use the `.transform()` method to make predictions and save them as `predictions`.

# %%
predictions = lrModel.transform(test)

# %% [markdown]
# 4. View the first 10 rows of the `predictions` DataFrame.

# %%
predictions.show(10)
# Out:
# +-----+--------------------+---+----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+--------------------+--------------------+----------+
# |label|            features|age|       job|marital|education|default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|  y|       rawPrediction|         probability|prediction|
# +-----+--------------------+---+----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+--------------------+--------------------+----------+
# |  0.0|(30,[0,11,13,16,1...| 34|management|married|secondary|     no|    857|    yes|  no|cellular| 22|  aug|     238|       6|   -1|       0| unknown| no|[3.01686749983334...|[0.95333035331606...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 42|management|married|secondary|     no|   -105|    yes|  no|cellular| 28|  aug|      60|       2|   -1|       0| unknown| no|[3.49654318936783...|[0.97058925233653...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 44|management|married|secondary|     no|   8262|    yes|  no|cellular| 23|  jul|     201|      16|   -1|       0| unknown| no|[3.94928457077307...|[0.98109577366574...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 31|management|married|secondary|     no|    625|    yes|  no|cellular|  7|  apr|     424|       1|  138|       1| failure| no|[1.63554587865929...|[0.83692795283879...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 36|management|married|secondary|     no|   1825|    yes|  no|cellular| 14|  may|      24|       1|  346|       1| failure| no|[3.57849520960090...|[0.97284055178547...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 32|management|married|secondary|     no|    350|    yes|  no| unknown| 28|  may|     110|       2|   -1|       0| unknown| no|[4.29984101328424...|[0.98661098215971...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 35|management|married|secondary|     no|    839|    yes|  no| unknown| 23|  may|      50|       3|   -1|       0| unknown| no|[4.62713316563006...|[0.99031201081150...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 36|management|married|secondary|     no|     80|    yes|  no| unknown| 30|  may|     251|       3|   -1|       0| unknown| no|[3.87711856125696...|[0.97970980331485...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 48|management|married|secondary|     no|     99|    yes|  no| unknown| 28|  may|     344|       1|   -1|       0| unknown| no|[3.51039386706840...|[0.97098206377994...|       0.0|
# |  0.0|(30,[0,11,13,16,1...| 49|management|married|secondary|     no|    362|    yes|  no| unknown|  4|  jun|      84|       2|   -1|       0| unknown| no|[4.57431953826219...|[0.98979196407912...|       0.0|
# +-----+--------------------+---+----------+-------+---------+-------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+---+--------------------+--------------------+----------+
# only showing top 10 rows

# %% [markdown]
# 5. What is the area under the curve?
#
#     You can find it with the `evaluator.evaluate()` function.

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator()
evaluator.evaluate(predictions)
# Out:
# 0.8553059414720642

# %% [markdown]
# ## OPTIONAL: HyperParameter Tuning a Gradient-Boosted Tree Classifier
#
# 1. Fit and make predictions using `GBTClassifier`. The syntax will match what we did above with `LogisticRegression`.

# %%
from pyspark.ml.classification import GBTClassifier

gbt = GBTClassifier(maxIter=10)
gbtModel = gbt.fit(train)
predictions = gbtModel.transform(test)
predictions.select('age', 'job', 'label', 'rawPrediction', 'prediction', 'probability').show(10)

# %% [markdown]
# 2. Perform cross-validation to compare different parameters.
#
#     Note that it can take a while because it's training over many gradient boosted trees. Give it at least 10 minutes to complete.

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
paramGrid = (ParamGridBuilder()
             .addGrid(gbt.maxDepth, [2, 4, 6])
             .addGrid(gbt.maxBins, [20, 60])
             .addGrid(gbt.maxIter, [10, 20])
             .build())
cv = CrossValidator(estimator=gbt, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)
cvModel = cv.fit(train)
predictions = cvModel.transform(test)
evaluator.evaluate(predictions)

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# This notebook is adapted from [Machine Learning with PySpark and MLlib](https://towardsdatascience.com/machine-learning-with-pyspark-and-mllib-solving-a-binary-classification-problem-96396065d2aa)
